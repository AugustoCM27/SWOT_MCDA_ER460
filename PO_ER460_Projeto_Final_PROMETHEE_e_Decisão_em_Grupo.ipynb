# %% [markdown]
# PO/ER460 - Projeto Final
#
# SELEÇÃO E ORDENAMENTO DE ELEMENTOS DA MATRIZ SWOT ATRAVÉS DE UMA ABORDAGEM MULTICRITÉRIO E DE DECISÕES EM GRUPO
#
# - Augusto Chebel Machado (231762)
# - Émerson José Ferri
# - Lucas Tramonte (182697)

# %% [markdown]
# # O que esse código faz?

# %% [markdown]
# - A partir do método PROMETHEE, realizamos o ordenamento para cada quadrante da matriz SWOT (Oportunidades, Ameaças, Pontos Fracos e Pontos Fortes);
# - Cada decisor gera seu ordenamento;
# - Após o ordenamento individual, através dos métodos de Borda e de Condorcet para decisões em grupo, gera-se os ordenamentos para o conjunto de decisores.

# %% [markdown]
# # Importando bibliotecas e acessando o Drive

# %%
#Importando bibliotecas e acessando o Drive
import pandas as pd
import numpy as np

# %%
# !pip install gspread
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gspread in /usr/local/lib/python3.8/dist-packages (3.4.2)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.8/dist-packages (from gspread) (2.15.0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from gspread) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.2.1->gspread) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.2.1->gspread) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.2.1->gspread) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.2.1->gspread) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth->gspread) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth->gspread) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth->gspread) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth->gspread) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth->gspread) (0.4.8)

# %%
#Código que importa dados do Google Sheets

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

from google.colab import files

# %% [markdown]
# # Definindo as funções para rodar o PROMETHEE

# %%
# funções de preferência
def f_pref(df, criterio, tipo, func='usual', q=0, p=0):
  n_alt = len(df)
  m = np.zeros([n_alt, n_alt])
  for i in range(0, n_alt):
    for j in range(0, n_alt):
      if tipo == 'max':
        d = df[criterio][i] - df[criterio][j]
      elif tipo == 'min':
        d = df[criterio][j] - df[criterio][i]

      if func == 'usual':
        if d <= 0:
          m[i][j] = 0
        else:
          m[i][j] = 1

      if func == 'U':
        if d <= q:
          m[i][j] = 0
        else:
          m[i][j] = 1

      if func == 'níveis':
        if d <= 0:
          m[i][j] = 0
        elif q < d <= p:
          m[i][j] = 1/2
        else:
          m[i][j] = 1

      if func == 'linear':
        if d <= q:
          m[i][j] = 0
        elif q < d <= p:
          m[i][j] = (d-q)/(p-q)
        else:
          m[i][j] = 1

  return m

# cálculo dos fluxos
def fluxo_pos(M):
  fluxo_pos = []
  for i in range(0, len(M)):
    phi = sum(M[i])/(len(M)-1)
    fluxo_pos.append(phi)
  return np.array(fluxo_pos)

def fluxo_neg(M):
  fluxo_neg = []
  for j in range(0, len(M)):
    phi = sum(M[...,j])/(len(M)-1)
    fluxo_neg.append(phi)
  return np.array(fluxo_neg)

def fluxo_liq(fluxo_pos, fluxo_neg):
  fluxo_liq = fluxo_pos - fluxo_neg
  return fluxo_liq

# %% [markdown]
# # Importando e definindo as funções para o Método de Condorcet

# %%
# !pip install condorcet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: condorcet in /usr/local/lib/python3.8/dist-packages (0.1.1)
# Requirement already satisfied: pytest-mock<4.0.0,>=3.6.1 in /usr/local/lib/python3.8/dist-packages (from condorcet) (3.10.0)
# Requirement already satisfied: pytest>=5.0 in /usr/local/lib/python3.8/dist-packages (from pytest-mock<4.0.0,>=3.6.1->condorcet) (7.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (22.1.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (1.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->pytest>=5.0->pytest-mock<4.0.0,>=3.6.1->condorcet) (3.0.9)

# %%
import condorcet

# %%
def voto(lista_df):
  votos = []
  for df in lista_df:
    voto_decisor = {}
    for i in range(0, len(df)):
      voto_decisor.update({df.index.values[i] : i+1})
    votos.append(voto_decisor)
  return votos

# %% [markdown]
# # Oportunidades

# %%
# Importando os dados do problema (oportunidades)

oport_a1 = pd.DataFrame(gc.open('PO/ER460 - Oportunidades').get_worksheet(0).get_all_records())
oport_a2 = pd.DataFrame(gc.open('PO/ER460 - Oportunidades').get_worksheet(1).get_all_records())
oport_a3 = pd.DataFrame(gc.open('PO/ER460 - Oportunidades').get_worksheet(2).get_all_records())
oport_a4 = pd.DataFrame(gc.open('PO/ER460 - Oportunidades').get_worksheet(3).get_all_records())
# oport_a5 = pd.DataFrame(gc.open('PO/ER460 - Oportunidades').get_worksheet(4).get_all_records())

# %%
# tornando as alternativas como índices
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

oport_a1 = indice(oport_a1)
oport_a2 = indice(oport_a2)
oport_a3 = indice(oport_a3)
oport_a4 = indice(oport_a4)
# oport_a5 = indice(oport_a5)

# %%
# criando uma escala numérica e passando para o df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Probabilidade'] = df['Probabilidade'].map(dic)
  df['Custo'] = df['Custo'].map(dic)
  df['Benefício'] = df['Benefício'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

oport_a1 = escala(oport_a1)
oport_a2 = escala(oport_a2)
oport_a3 = escala(oport_a3)
oport_a4 = escala(oport_a4)
# oport_a5 = escala(oport_a5)

# %%
# criando função para calcular a matriz de preferência M
def M_oport(df, w):
  m_fortes = f_pref(df, 'Pontos Fortes', 'linear', 'max', q=1, p=4)
  m_fracos = f_pref(df, 'Pontos Fracos', 'linear', 'min', q=1, p=4)
  m_prob = f_pref(df, 'Probabilidade', 'max')
  m_custo = f_pref(df, 'Custo', 'min')
  m_benef = f_pref(df, 'Benefício', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_fortes, m_fracos, m_prob, m_custo, m_benef, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vetor de pesos
w_oport = [0.21, 0.09, 0.13, 0.11, 0.12, 0.34]

# cálculo das matrizes de preferência para cada decisor (oportunidades):
M_a1 = M_oport(oport_a1, w_oport)
M_a2 = M_oport(oport_a2, w_oport)
M_a3 = M_oport(oport_a3, w_oport)
M_a4 = M_oport(oport_a4, w_oport)
# M_a5 = M_oport(oport_a5, w_oport)

# %%
# calculando o fluxo líquido
def fl_oport(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_oport(M_a1)
fl_a2 = fl_oport(M_a2)
fl_a3 = fl_oport(M_a3)
fl_a4 = fl_oport(M_a4)
# fl_a5 = fl_oport(M_a5)

# %%
# # função para ordenamento
# def ordenamento(df, fl):
#   # gerando um dicionário para ranking
#   rank = {}
#   for i in range(0, len(df)):
#     rank.update({df.index.values[i] : fl[i]})

#   # gerando a ordem (decrescente)
#   ordem = []
#   for i in sorted(rank, key=rank.get, reverse=True):
#     ordem.append(i)
#     # print(i, rank[i])

#   print('O ranking das oportunidades é:')
#   for i in range(0, len(ordem)):
#     print(f'{i+1}° - {ordem[i]}')

# %%
# função para ordenamento
def ordenamento(decisor, df, fl):
  # gerando um dicionário para ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, oport_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, oport_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, oport_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, oport_a4, fl_a4))
# print(80*'-')
# print('Avaliador 5:')
# print(ordenamento(5, oport_a5, fl_a5))
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Crescimento do tema sustentabilidade                     0.420909        1
# Recursos para projetos obras e ações                     0.339091        2
# Uso da tecnologia BIM                                    0.111818        3
# Melhoria do trabalho com uso das TIC                     0.052727        4
# Eventos da Universidade                                  0.020909        5
# Interesse de agentes externos para novas parcerias      -0.002727        6
# Representação em órgãos externos                        -0.011818        7
# Fundo patronos, nova via de financiamento das a...      -0.052727        8
# Valorização e reconhecimento das competências i...      -0.117273        9
# Inovação do ambiente universitário                      -0.167273       10
# Lei de licitações 14.133 otimizando o processo ...      -0.198182       11
# Amparo e segurança legal                                -0.395455       12
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Crescimento do tema sustentabilidade                     0.539091        1
# Inovação do ambiente universitário                       0.245455        2
# Uso da tecnologia BIM                                    0.165455        3
# Interesse de agentes externos para novas parcerias       0.129091        4
# Eventos da Universidade                                  0.073636        5
# Recursos para projetos obras e ações                     0.029091        6
# Melhoria do trabalho com uso das TIC                    -0.030909        7
# Lei de licitações 14.133 otimizando o processo ...      -0.104545        8
# Fundo patronos, nova via de financiamento das a...      -0.156364        9
# Representação em órgãos externos                        -0.244545       10
# Valorização e reconhecimento das competências i...      -0.250909       11
# Amparo e segurança legal                                -0.394545       12
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Crescimento do tema sustentabilidade                 5.354545e-01        1
# Recursos para projetos obras e ações                 4.736364e-01        2
# Uso da tecnologia BIM                                7.636364e-02        3
# Lei de licitações 14.133 otimizando o processo ...   5.000000e-02        4
# Inovação do ambiente universitário                   5.000000e-02        5
# Melhoria do trabalho com uso das TIC                -5.551115e-17        6
# Interesse de agentes externos para novas parcerias  -2.727273e-02        7
# Valorização e reconhecimento das competências i...  -5.636364e-02        8
# Fundo patronos, nova via de financiamento das a...  -5.636364e-02        9
# Amparo e segurança legal                            -2.354545e-01       10
# Eventos da Universidade                             -2.900000e-01       11
# Representação em órgãos externos                    -5.200000e-01       12
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Eventos da Universidade                                  0.273636        1
# Crescimento do tema sustentabilidade                     0.213636        2
# Inovação do ambiente universitário                       0.213636        3
# Amparo e segurança legal                                 0.163636        4
# Interesse de agentes externos para novas parcerias       0.163636        5
# Recursos para projetos obras e ações                     0.069091        6
# Uso da tecnologia BIM                                   -0.066364        7
# Fundo patronos, nova via de financiamento das a...      -0.066364        8
# Lei de licitações 14.133 otimizando o processo ...      -0.207273        9
# Valorização e reconhecimento das competências i...      -0.231818       10
# Melhoria do trabalho com uso das TIC                    -0.246364       11
# Representação em órgãos externos                        -0.279091       12

# %%
# gerando as tabelas para cada decisor (oportunidades)

ordem_oport_a1 = ordenamento(1, oport_a1, fl_a1)
ordem_oport_a2 = ordenamento(2, oport_a2, fl_a2)
ordem_oport_a3 = ordenamento(3, oport_a3, fl_a3)
ordem_oport_a4 = ordenamento(4, oport_a4, fl_a4)
# ordem_oport_a5 = ordenamento(5, oport_a5, fl_a5)

# criando um dataframe com os ordenamento de todos os decisores:
oportuni = pd.concat([ordem_oport_a1, ordem_oport_a2, ordem_oport_a3, ordem_oport_a4], axis=1)
oportuni
oportuni = oportuni.drop(['Fluxo Líquido'], axis=1)
oportuni
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Crescimento do tema sustentabilidade                      1        1        1
# Recursos para projetos obras e ações                      2        6        2
# Uso da tecnologia BIM                                     3        3        3
# Melhoria do trabalho com uso das TIC                      4        7        6
# Eventos da Universidade                                   5        5       11
# Interesse de agentes externos para novas parcerias        6        4        7
# Representação em órgãos externos                          7       10       12
# Fundo patronos, nova via de financiamento das a...        8        9        9
# Valorização e reconhecimento das competências i...        9       11        8
# Inovação do ambiente universitário                       10        2        5
# Lei de licitações 14.133 otimizando o processo ...       11        8        4
# Amparo e segurança legal                                 12       12       10
#
#                                                     Rank D4
# Crescimento do tema sustentabilidade                      2
# Recursos para projetos obras e ações                      6
# Uso da tecnologia BIM                                     7
# Melhoria do trabalho com uso das TIC                     11
# Eventos da Universidade                                   1
# Interesse de agentes externos para novas parcerias        5
# Representação em órgãos externos                         12
# Fundo patronos, nova via de financiamento das a...        8
# Valorização e reconhecimento das competências i...       10
# Inovação do ambiente universitário                        3
# Lei de licitações 14.133 otimizando o processo ...        9
# Amparo e segurança legal                                  4

# %%
#@title Decisão em Grupo (Borda):
# criando uma escala para borda
borda_oport = {}
for i in range(0, len(oportuni)):
  borda_oport.update({i+1: (len(oportuni)-i)})

peso_dirigente = 1.2
borda_oport_dirig = {}
for i in range(0, len(oportuni)):
  borda_oport_dirig.update({i+1: (len(oportuni)-i)*peso_dirigente})

# substituindo os valores de ordenamento pelo valor da escala de Borda
# Ex: (1,2,3) vai virar (3,2,1)
for i in oportuni.columns:
  if i == oportuni.columns[0]: # se o decisor for a dirigente (peso maior)
    oportuni[i] = oportuni[i].map(borda_oport_dirig)
  else:
    oportuni[i] = oportuni[i].map(borda_oport)

# somando os valores de cada alternativa
oportuni['Valor'] = oportuni.sum(axis=1)
# oportuni

oport_final = pd.DataFrame(oportuni['Valor'])
oport_final = oport_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(oport_final)):
  ord.append(f'{i+1}°')

oport_final['Ordem Final (Borda)'] = ord
oport_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Crescimento do tema sustentabilidade                 49.4                  1°
# Recursos para projetos obras e ações                 38.2                  2°
# Uso da tecnologia BIM                                38.0                  3°
# Inovação do ambiente universitário                   32.6                  4°
# Eventos da Universidade                              31.6                  5°
# Interesse de agentes externos para novas parcerias   31.4                  6°
# Melhoria do trabalho com uso das TIC                 25.8                  7°
# Lei de licitações 14.133 otimizando o processo ...   20.4                  8°
# Fundo patronos, nova via de financiamento das a...   19.0                  9°
# Valorização e reconhecimento das competências i...   14.8                 10°
# Amparo e segurança legal                             14.2                 11°
# Representação em órgãos externos                     12.2                 12°

# %%
#@title Decisão em grupo (Condorcet):

ordem_oport_a1 = ordenamento(1, oport_a1, fl_a1)
ordem_oport_a2 = ordenamento(2, oport_a2, fl_a2)
ordem_oport_a3 = ordenamento(3, oport_a3, fl_a3)
ordem_oport_a4 = ordenamento(4, oport_a4, fl_a4)

candidatos = ordem_oport_a1.index.values
candidatos = list(candidatos)

lista_oport = [ordem_oport_a1, ordem_oport_a2, ordem_oport_a3, ordem_oport_a4]
votos = voto(lista_oport)

# usando as funções da biblioteca condorcet para definir o ordenamento
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_oport_a1))

oport_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(oport_condorcet)):
  ord.append(f'{i+1}°')
oport_condorcet['Ordem Final (Condorcet)'] = ord

oport_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Crescimento do tema sustentabilidade                                    1°
# Recursos para projetos obras e ações                                    2°
# Uso da tecnologia BIM                                                   3°
# Eventos da Universidade                                                 4°
# Inovação do ambiente universitário                                      5°
# Melhoria do trabalho com uso das TIC                                    6°
# Interesse de agentes externos para novas parcerias                      7°
# Fundo patronos, nova via de financiamento das a...                      8°
# Lei de licitações 14.133 otimizando o processo ...                      9°
# Representação em órgãos externos                                       10°
# Valorização e reconhecimento das competências i...                     11°
# Amparo e segurança legal                                               12°

# %% [markdown]
# # Ameaças

# %%
# Importando os dados do problema (ameaças)

ameaça_a1 = pd.DataFrame(gc.open('PO/ER460 - Ameaças').get_worksheet(0).get_all_records())
ameaça_a2 = pd.DataFrame(gc.open('PO/ER460 - Ameaças').get_worksheet(1).get_all_records())
ameaça_a3 = pd.DataFrame(gc.open('PO/ER460 - Ameaças').get_worksheet(2).get_all_records())
ameaça_a4 = pd.DataFrame(gc.open('PO/ER460 - Ameaças').get_worksheet(3).get_all_records())
# ameaça_a5 = pd.DataFrame(gc.open('PO/ER460 - Ameaças').get_worksheet(4).get_all_records())

# %%
# tornando as alternativas como índices
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

ameaça_a1 = indice(ameaça_a1)
ameaça_a2 = indice(ameaça_a2)
ameaça_a3 = indice(ameaça_a3)
ameaça_a4 = indice(ameaça_a4)
# ameaça_a5 = indice(ameaça_a5)

# %%
# criando uma escala numérica e passando para o df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Probabilidade'] = df['Probabilidade'].map(dic)
  df['Custo'] = df['Custo'].map(dic)
  df['Impacto'] = df['Impacto'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

ameaça_a1 = escala(ameaça_a1)
ameaça_a2 = escala(ameaça_a2)
ameaça_a3 = escala(ameaça_a3)
ameaça_a4 = escala(ameaça_a4)
# ameaça_a5 = escala(ameaça_a5)

# %%
# criando função para calcular a matriz de preferência M
def M_ameaca(df, w):
  m_fracos = f_pref(df, 'Pontos Fracos', 'min', 'linear', q=1, p=4)
  m_fortes = f_pref(df, 'Pontos Fortes', 'max', 'linear', q=1, p=4)
  m_prob = f_pref(df, 'Probabilidade', 'max')
  m_custo = f_pref(df, 'Custo', 'min')
  m_impac = f_pref(df, 'Impacto', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_fortes, m_fracos, m_prob, m_custo, m_impac, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vetor de pesos
w_ameaça = [0.18, 0.12, 0.18, 0.08, 0.12, 0.32]

# cálculo das matrizes de preferência para cada decisor (ameaças):
M_a1 = M_ameaca(ameaça_a1, w_ameaça)
M_a2 = M_ameaca(ameaça_a2, w_ameaça)
M_a3 = M_ameaca(ameaça_a3, w_ameaça)
M_a4 = M_ameaca(ameaça_a4, w_ameaça)
# M_a5 = M_ameaca(ameaça_a5, w_ameaça)

# %%
# calculando o fluxo líquido
def fl_ameaca(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_ameaca(M_a1)
fl_a2 = fl_ameaca(M_a2)
fl_a3 = fl_ameaca(M_a3)
fl_a4 = fl_ameaca(M_a4)
# fl_a5 = fl_ameaca(M_a5)

# %%
# # função para ordenamento
# def ordenamento(df, fl):
#   # gerando um dicionário para ranking
#   rank = {}
#   for i in range(0, len(df)):
#     rank.update({df.index.values[i] : fl[i]})

#   # gerando a ordem (decrescente)
#   ordem = []
#   for i in sorted(rank, key=rank.get, reverse=True):
#     ordem.append(i)
#     # print(i, rank[i])

#   print('O ranking das oportunidades é:')
#   for i in range(0, len(ordem)):
#     print(f'{i+1}° - {ordem[i]}')

# %%
# função para ordenamento
def ordenamento(decisor, df, fl):
  # gerando um dicionário para ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, ameaça_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, ameaça_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, ameaça_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, ameaça_a4, fl_a4))
# print(80*'-')
# print('Avaliador 5:')
# print(ordenamento(5, ameaça_a5, fl_a5))
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Resistência da comunidade universitária à polít...       0.509412        1
# Crescimento da demanda além da capacidade opera...       0.445882        2
# Falta de infraestrutura e resistência a automat...       0.351765        3
# HIDS: o início da ocupação da fazenda argentina...       0.291765        4
# Implicações orçamentárias                                0.241176        5
# Baixa qualidade das empresas/ produtos/ serviço...       0.227059        6
# Dificuldade de interface com outras áreas técni...       0.216471        7
# Intrusão do novo governo do estado de São Paulo...       0.060000        8
# Mudança no cenário político                              0.060000        9
# Ameaças sanitárias                                       0.060000       10
# Obstrução da procuradoria geral da universidade         -0.025882       11
# Incertezas de critérios e volume de recursos pa...      -0.045882       12
# Perda de talentos                                       -0.175294       13
# Interesses pessoais acima das desições técnicas         -0.342353       14
# Deterioração do patrimônio edificado da Unicamp         -0.378824       15
# Vulnerabilidade dos sistemas automatizados pode...      -0.431765       16
# Despreparo para trabalhar a inclusão podendo ge...      -0.500000       17
# Revogação e ou abrandamento das legislações vig...      -0.563529       18
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Resistência da comunidade universitária à polít...       0.362353        1
# Falta de infraestrutura e resistência a automat...       0.351765        2
# Despreparo para trabalhar a inclusão podendo ge...       0.276471        3
# Dificuldade de interface com outras áreas técni...       0.177647        4
# HIDS: o início da ocupação da fazenda argentina...       0.169412        5
# Baixa qualidade das empresas/ produtos/ serviço...       0.134118        6
# Deterioração do patrimônio edificado da Unicamp          0.088235        7
# Mudança no cenário político                              0.084706        8
# Perda de talentos                                        0.077647        9
# Implicações orçamentárias                                0.036471       10
# Intrusão do novo governo do estado de São Paulo...       0.018824       11
# Crescimento da demanda além da capacidade opera...       0.012941       12
# Obstrução da procuradoria geral da universidade         -0.074118       13
# Interesses pessoais acima das desições técnicas         -0.165882       14
# Ameaças sanitárias                                      -0.212941       15
# Revogação e ou abrandamento das legislações vig...      -0.263529       16
# Vulnerabilidade dos sistemas automatizados pode...      -0.441176       17
# Incertezas de critérios e volume de recursos pa...      -0.632941       18
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Crescimento da demanda além da capacidade opera...       0.487059        1
# Interesses pessoais acima das desições técnicas          0.254118        2
# Resistência da comunidade universitária à polít...       0.231765        3
# Perda de talentos                                        0.220000        4
# Incertezas de critérios e volume de recursos pa...       0.190588        5
# Deterioração do patrimônio edificado da Unicamp          0.056471        6
# Implicações orçamentárias                                0.047059        7
# Obstrução da procuradoria geral da universidade          0.029412        8
# Despreparo para trabalhar a inclusão podendo ge...       0.008235        9
# Dificuldade de interface com outras áreas técni...      -0.002353       10
# Baixa qualidade das empresas/ produtos/ serviço...      -0.009412       11
# Ameaças sanitárias                                      -0.037647       12
# HIDS: o início da ocupação da fazenda argentina...      -0.038824       13
# Mudança no cenário político                             -0.097647       14
# Revogação e ou abrandamento das legislações vig...      -0.162353       15
# Falta de infraestrutura e resistência a automat...      -0.227059       16
# Intrusão do novo governo do estado de São Paulo...      -0.401176       17
# Vulnerabilidade dos sistemas automatizados pode...      -0.548235       18
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Resistência da comunidade universitária à polít...       0.440000        1
# Perda de talentos                                        0.337647        2
# Intrusão do novo governo do estado de São Paulo...       0.261176        3
# Ameaças sanitárias                                       0.227059        4
# Baixa qualidade das empresas/ produtos/ serviço...       0.218824        5
# Dificuldade de interface com outras áreas técni...       0.216471        6
# Mudança no cenário político                              0.188235        7
# Crescimento da demanda além da capacidade opera...       0.171765        8
# HIDS: o início da ocupação da fazenda argentina...       0.128235        9
# Interesses pessoais acima das desições técnicas          0.036471       10
# Incertezas de critérios e volume de recursos pa...       0.007059       11
# Deterioração do patrimônio edificado da Unicamp         -0.135294       12
# Implicações orçamentárias                               -0.161176       13
# Falta de infraestrutura e resistência a automat...      -0.174118       14
# Obstrução da procuradoria geral da universidade         -0.409412       15
# Vulnerabilidade dos sistemas automatizados pode...      -0.412941       16
# Despreparo para trabalhar a inclusão podendo ge...      -0.414118       17
# Revogação e ou abrandamento das legislações vig...      -0.525882       18

# %%
# gerando as tabelas para cada decisor (ameaças)
ordem_ameaça_a1 = ordenamento(1, ameaça_a1, fl_a1)
ordem_ameaça_a2 = ordenamento(2, ameaça_a2, fl_a2)
ordem_ameaça_a3 = ordenamento(3, ameaça_a3, fl_a3)
ordem_ameaça_a4 = ordenamento(4, ameaça_a4, fl_a4)
# ordem_ameaça_a5 = ordenamento(5, ameaça_a5, fl_a5)

# criando um dataframe com os ordenamento de todos os decisores:
ameaça = pd.concat([ordem_ameaça_a1, ordem_ameaça_a2, ordem_ameaça_a3, ordem_ameaça_a4], axis=1)
ameaça = ameaça.drop(['Fluxo Líquido'], axis=1)
ameaça
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Resistência da comunidade universitária à polít...        1        1        3
# Crescimento da demanda além da capacidade opera...        2       12        1
# Falta de infraestrutura e resistência a automat...        3        2       16
# HIDS: o início da ocupação da fazenda argentina...        4        5       13
# Implicações orçamentárias                                 5       10        7
# Baixa qualidade das empresas/ produtos/ serviço...        6        6       11
# Dificuldade de interface com outras áreas técni...        7        4       10
# Intrusão do novo governo do estado de São Paulo...        8       11       17
# Mudança no cenário político                               9        8       14
# Ameaças sanitárias                                       10       15       12
# Obstrução da procuradoria geral da universidade          11       13        8
# Incertezas de critérios e volume de recursos pa...       12       18        5
# Perda de talentos                                        13        9        4
# Interesses pessoais acima das desições técnicas          14       14        2
# Deterioração do patrimônio edificado da Unicamp          15        7        6
# Vulnerabilidade dos sistemas automatizados pode...       16       17       18
# Despreparo para trabalhar a inclusão podendo ge...       17        3        9
# Revogação e ou abrandamento das legislações vig...       18       16       15
#
#                                                     Rank D4
# Resistência da comunidade universitária à polít...        1
# Crescimento da demanda além da capacidade opera...        8
# Falta de infraestrutura e resistência a automat...       14
# HIDS: o início da ocupação da fazenda argentina...        9
# Implicações orçamentárias                                13
# Baixa qualidade das empresas/ produtos/ serviço...        5
# Dificuldade de interface com outras áreas técni...        6
# Intrusão do novo governo do estado de São Paulo...        3
# Mudança no cenário político                               7
# Ameaças sanitárias                                        4
# Obstrução da procuradoria geral da universidade          15
# Incertezas de critérios e volume de recursos pa...       11
# Perda de talentos                                         2
# Interesses pessoais acima das desições técnicas          10
# Deterioração do patrimônio edificado da Unicamp          12
# Vulnerabilidade dos sistemas automatizados pode...       16
# Despreparo para trabalhar a inclusão podendo ge...       17
# Revogação e ou abrandamento das legislações vig...       18

# %%
#@title Decisão em Grupo (Borda):
# criando uma escala para borda
borda_ameaça = {}
for i in range(0, len(ameaça)):
  borda_ameaça.update({i+1: (len(ameaça)-i)})

peso_dirigente = 1.2
borda_ameaça_dirig = {}
for i in range(0, len(ameaça)):
  borda_ameaça_dirig.update({i+1: (len(ameaça)-i)*peso_dirigente})

# substituindo os valores de ordenamento pelo valor da escala de Borda
# Ex: (1,2,3) vai virar (3,2,1)
for i in ameaça.columns:
  if i == ameaça.columns[0]: # se o decisor for a dirigente (peso maior)
    ameaça[i] = ameaça[i].map(borda_ameaça_dirig)
  else:
    ameaça[i] = ameaça[i].map(borda_ameaça)

# somando os valores de cada alternativa
ameaça['Valor'] = ameaça.sum(axis=1)
# ameaça

ameaça_final = pd.DataFrame(ameaça['Valor'])
ameaça_final = ameaça_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(ameaça_final)):
  ord.append(f'{i+1}°')

ameaça_final['Ordem Final (Borda)'] = ord
ameaça_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Resistência da comunidade universitária à polít...   73.6                  1°
# Crescimento da demanda além da capacidade opera...   56.4                  2°
# Dificuldade de interface com outras áreas técni...   51.4                  3°
# Baixa qualidade das empresas/ produtos/ serviço...   50.6                  4°
# Perda de talentos                                    49.2                  5°
# HIDS: o início da ocupação da fazenda argentina...   48.0                  6°
# Falta de infraestrutura e resistência a automat...   44.2                  7°
# Implicações orçamentárias                            43.8                  8°
# Mudança no cenário político                          40.0                  9°
# Intrusão do novo governo do estado de São Paulo...   39.2                 10°
# Interesses pessoais acima das desições técnicas      37.0                 11°
# Deterioração do patrimônio edificado da Unicamp      36.8                 12°
# Ameaças sanitárias                                   36.8                 13°
# Incertezas de critérios e volume de recursos pa...   31.4                 14°
# Obstrução da procuradoria geral da universidade      30.6                 15°
# Despreparo para trabalhar a inclusão podendo ge...   30.4                 16°
# Vulnerabilidade dos sistemas automatizados pode...    9.6                 17°
# Revogação e ou abrandamento das legislações vig...    9.2                 18°

# %%
#@title Decisão em Grupo (Condorcet):

ordem_ameaça_a1 = ordenamento(1, ameaça_a1, fl_a1)
ordem_ameaça_a2 = ordenamento(2, ameaça_a2, fl_a2)
ordem_ameaça_a3 = ordenamento(3, ameaça_a3, fl_a3)
ordem_ameaça_a4 = ordenamento(4, ameaça_a4, fl_a4)

candidatos = ordem_ameaça_a1.index.values
candidatos = list(candidatos)

lista_ameaça = [ordem_ameaça_a1, ordem_ameaça_a2, ordem_ameaça_a3, ordem_ameaça_a4]
votos = voto(lista_ameaça)

# usando as funções da biblioteca condorcet para definir o ordenamento
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_ameaça_a1))

ameaça_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(ameaça_condorcet)):
  ord.append(f'{i+1}°')
ameaça_condorcet['Ordem Final (Condorcet)'] = ord

ameaça_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Resistência da comunidade universitária à polít...                      1°
# Crescimento da demanda além da capacidade opera...                      2°
# Falta de infraestrutura e resistência a automat...                      3°
# Baixa qualidade das empresas/ produtos/ serviço...                      4°
# Dificuldade de interface com outras áreas técni...                      5°
# HIDS: o início da ocupação da fazenda argentina...                      6°
# Mudança no cenário político                                             7°
# Perda de talentos                                                       8°

# %% [markdown]
# # Pontos Fracos

# %%
# Importando os dados do problema (pontos fracos)

fraco_a1 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fracos').get_worksheet(0).get_all_records())
fraco_a2 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fracos').get_worksheet(1).get_all_records())
fraco_a3 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fracos').get_worksheet(2).get_all_records())
fraco_a4 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fracos').get_worksheet(3).get_all_records())
# fraco_a5 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fracos').get_worksheet(4).get_all_records())

# %%
# tornando as alternativas como índices
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

fraco_a1 = indice(fraco_a1)
fraco_a2 = indice(fraco_a2)
fraco_a3 = indice(fraco_a3)
fraco_a4 = indice(fraco_a4)
# fraco_a5 = indice(fraco_a5)

# %%
# criando uma escala numérica e passando para o df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Custo'] = df['Custo'].map(dic)
  df['Retorno'] = df['Retorno'].map(dic)
  df['Missão'] = df['Missão'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

fraco_a1 = escala(fraco_a1)
fraco_a2 = escala(fraco_a2)
fraco_a3 = escala(fraco_a3)
fraco_a4 = escala(fraco_a4)
# fraco_a5 = escala(fraco_a5)

# %%
# criando função para calcular a matriz de preferência M
def M_fraco(df, w):
  m_pot_ame = f_pref(df, 'Pot. Ameaças', 'max', 'linear', q=1, p=4)
  m_dif_oport = f_pref(df, 'Dif. Oport.', 'max', 'linear', q=1, p=4)
  m_custo = f_pref(df, 'Custo', 'min')
  m_ret = f_pref(df, 'Retorno', 'max')
  m_missao = f_pref(df, 'Missão', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_pot_ame, m_dif_oport, m_custo, m_ret, m_missao, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vetor de pesos
w_fraco = [0.09, 0.06, 0.12, 0.10, 0.23, 0.40]

# cálculo das matrizes de preferência para cada decisor (pontos fracos):
M_a1 = M_fraco(fraco_a1, w_fraco)
M_a2 = M_fraco(fraco_a2, w_fraco)
M_a3 = M_fraco(fraco_a3, w_fraco)
M_a4 = M_fraco(fraco_a4, w_fraco)
# M_a5 = M_fraco(fraco_a5, w_fraco)

# %%
# calculando o fluxo líquido
def fl_fraco(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_fraco(M_a1)
fl_a2 = fl_fraco(M_a2)
fl_a3 = fl_fraco(M_a3)
fl_a4 = fl_fraco(M_a4)
# fl_a5 = fl_fraco(M_a5)

# %%
# # função para ordenamento
# def ordenamento(df, fl):
#   # gerando um dicionário para ranking
#   rank = {}
#   for i in range(0, len(df)):
#     rank.update({df.index.values[i] : fl[i]})

#   # gerando a ordem (decrescente)
#   ordem = []
#   for i in sorted(rank, key=rank.get, reverse=True):
#     ordem.append(i)
#     # print(i, rank[i])

#   print('O ranking das oportunidades é:')
#   for i in range(0, len(ordem)):
#     print(f'{i+1}° - {ordem[i]}')

# %%
# função para ordenamento
def ordenamento(decisor, df, fl):
  # gerando um dicionário para ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, fraco_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, fraco_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, fraco_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, fraco_a4, fl_a4))
# print(80*'-')
# print('Avaliador 5:')
# print(ordenamento(5, fraco_a5, fl_a5))
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Falta de clareza dos objetivos a serem alcançados        0.767500        1
# Processos de trabalhos pouco definidos                   0.761667        2
# Falta de sistema de informação adequado ao proc...       0.499167        3
# Comunicação institucional deficiente                     0.391667        4
# Falta de integração entre os setores da DEPI             0.056667        5
# Falta de pessoal                                        -0.016667        6
# Oferecer poucos treinamentos na universidade da...      -0.021667        7
# Falha de comunicação interna entre as equipes           -0.031667        8
# Falta de conhecimento do usuário sobre os servi...      -0.241667        9
# Indefinição sobre a área de projetos de empreen...      -0.255833       10
# Talentos pouco explorados                               -0.460000       11
# Demora no retorno de algumas solicitações               -0.634167       12
# Separação física das equipes                            -0.815000       13
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Processos de trabalhos pouco definidos                   0.581667        1
# Falta de sistema de informação adequado ao proc...       0.543333        2
# Falta de clareza dos objetivos a serem alcançados        0.381667        3
# Falta de integração entre os setores da DEPI             0.355000        4
# Indefinição sobre a área de projetos de empreen...       0.180833        5
# Demora no retorno de algumas solicitações                0.177500        6
# Comunicação institucional deficiente                    -0.039167        7
# Talentos pouco explorados                               -0.230833        8
# Oferecer poucos treinamentos na universidade da...      -0.294167        9
# Falha de comunicação interna entre as equipes           -0.375000       10
# Falta de conhecimento do usuário sobre os servi...      -0.390833       11
# Falta de pessoal                                        -0.428333       12
# Separação física das equipes                            -0.461667       13
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Falta de clareza dos objetivos a serem alcançados        0.670000        1
# Processos de trabalhos pouco definidos                   0.495833        2
# Falta de conhecimento do usuário sobre os servi...       0.380000        3
# Falta de integração entre os setores da DEPI             0.309167        4
# Indefinição sobre a área de projetos de empreen...       0.225000        5
# Talentos pouco explorados                                0.176667        6
# Falha de comunicação interna entre as equipes           -0.018333        7
# Demora no retorno de algumas solicitações               -0.041667        8
# Comunicação institucional deficiente                    -0.163333        9
# Falta de pessoal                                        -0.268333       10
# Oferecer poucos treinamentos na universidade da...      -0.433333       11
# Falta de sistema de informação adequado ao proc...      -0.436667       12
# Separação física das equipes                            -0.895000       13
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Processos de trabalhos pouco definidos                   0.515833        1
# Oferecer poucos treinamentos na universidade da...       0.409167        2
# Falta de sistema de informação adequado ao proc...       0.355833        3
# Indefinição sobre a área de projetos de empreen...       0.342500        4
# Falta de conhecimento do usuário sobre os servi...       0.290000        5
# Comunicação institucional deficiente                     0.240000        6
# Falta de clareza dos objetivos a serem alcançados        0.140833        7
# Falta de pessoal                                         0.067500        8
# Talentos pouco explorados                               -0.080000        9
# Falha de comunicação interna entre as equipes           -0.137500       10
# Falta de integração entre os setores da DEPI            -0.626667       11
# Demora no retorno de algumas solicitações               -0.688333       12
# Separação física das equipes                            -0.829167       13

# %%
# gerando as tabelas para cada decisor (pontos fracos)
ordem_fraco_a1 = ordenamento(1, fraco_a1, fl_a1)
ordem_fraco_a2 = ordenamento(2, fraco_a2, fl_a2)
ordem_fraco_a3 = ordenamento(3, fraco_a3, fl_a3)
ordem_fraco_a4 = ordenamento(4, fraco_a4, fl_a4)
# ordem_fraco_a5 = ordenamento(5, fraco_a5, fl_a5)

# criando um dataframe com os ordenamento de todos os decisores:
pont_fracos = pd.concat([ordem_fraco_a1, ordem_fraco_a2, ordem_fraco_a3, ordem_fraco_a4], axis=1)
pont_fracos = pont_fracos.drop(['Fluxo Líquido'], axis=1)
pont_fracos
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Falta de clareza dos objetivos a serem alcançados         1        3        1
# Processos de trabalhos pouco definidos                    2        1        2
# Falta de sistema de informação adequado ao proc...        3        2       12
# Comunicação institucional deficiente                      4        7        9
# Falta de integração entre os setores da DEPI              5        4        4
# Falta de pessoal                                          6       12       10
# Oferecer poucos treinamentos na universidade da...        7        9       11
# Falha de comunicação interna entre as equipes             8       10        7
# Falta de conhecimento do usuário sobre os servi...        9       11        3
# Indefinição sobre a área de projetos de empreen...       10        5        5
# Talentos pouco explorados                                11        8        6
# Demora no retorno de algumas solicitações                12        6        8
# Separação física das equipes                             13       13       13
#
#                                                     Rank D4
# Falta de clareza dos objetivos a serem alcançados         7
# Processos de trabalhos pouco definidos                    1
# Falta de sistema de informação adequado ao proc...        3
# Comunicação institucional deficiente                      6
# Falta de integração entre os setores da DEPI             11
# Falta de pessoal                                          8
# Oferecer poucos treinamentos na universidade da...        2
# Falha de comunicação interna entre as equipes            10
# Falta de conhecimento do usuário sobre os servi...        5
# Indefinição sobre a área de projetos de empreen...        4
# Talentos pouco explorados                                 9
# Demora no retorno de algumas solicitações                12
# Separação física das equipes                             13

# %%
#@title Decisão em Grupo (Borda):
# criando uma escala para borda
borda_fraco = {}
for i in range(0, len(pont_fracos)):
  borda_fraco.update({i+1: (len(pont_fracos)-i)})

peso_dirigente = 1.2
borda_fraco_dirig = {}
for i in range(0, len(pont_fracos)):
  borda_fraco_dirig.update({i+1: (len(pont_fracos)-i)*peso_dirigente})

# substituindo os valores de ordenamento pelo valor da escala de Borda
# Ex: (1,2,3) vai virar (3,2,1)
for i in pont_fracos.columns:
  if i == pont_fracos.columns[0]: # se o decisor for a dirigente (peso maior)
    pont_fracos[i] = pont_fracos[i].map(borda_fraco_dirig)
  else:
    pont_fracos[i] = pont_fracos[i].map(borda_fraco)

# somando os valores de cada alternativa
pont_fracos['Valor'] = pont_fracos.sum(axis=1)
# pont_fracos

pont_fracos_final = pd.DataFrame(pont_fracos['Valor'])
pont_fracos_final = pont_fracos_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(pont_fracos_final)):
  ord.append(f'{i+1}°')

pont_fracos_final['Ordem Final (Borda)'] = ord
pont_fracos_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Processos de trabalhos pouco definidos               52.4                  1°
# Falta de clareza dos objetivos a serem alcançados    46.6                  2°
# Falta de sistema de informação adequado ao proc...   38.2                  3°
# Falta de integração entre os setores da DEPI         33.8                  4°
# Indefinição sobre a área de projetos de empreen...   32.8                  5°
# Comunicação institucional deficiente                 32.0                  6°
# Falta de conhecimento do usuário sobre os servi...   29.0                  7°
# Oferecer poucos treinamentos na universidade da...   28.4                  8°
# Talentos pouco explorados                            22.6                  9°
# Falha de comunicação interna entre as equipes        22.2                 10°
# Falta de pessoal                                     21.6                 11°
# Demora no retorno de algumas solicitações            18.4                 12°
# Separação física das equipes                          4.2                 13°

# %%
#@title Decisão em Grupo (Condorcet):

ordem_fraco_a1 = ordenamento(1, fraco_a1, fl_a1)
ordem_fraco_a2 = ordenamento(2, fraco_a2, fl_a2)
ordem_fraco_a3 = ordenamento(3, fraco_a3, fl_a3)
ordem_fraco_a4 = ordenamento(4, fraco_a4, fl_a4)

candidatos = ordem_fraco_a1.index.values
candidatos = list(candidatos)

lista_fraco = [ordem_fraco_a1, ordem_fraco_a2, ordem_fraco_a3, ordem_fraco_a4]
votos = voto(lista_fraco)

# usando as funções da biblioteca condorcet para definir o ordenamento
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_ameaça_a1))

fraco_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(fraco_condorcet)):
  ord.append(f'{i+1}°')
fraco_condorcet['Ordem Final (Condorcet)'] = ord

fraco_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Falta de clareza dos objetivos a serem alcançados                       1°
# Processos de trabalhos pouco definidos                                  2°
# Falta de sistema de informação adequado ao proc...                      3°
# Falta de integração entre os setores da DEPI                            4°
# Indefinição sobre a área de projetos de empreen...                      5°
# Comunicação institucional deficiente                                    6°
# Oferecer poucos treinamentos na universidade da...                      7°
# Falta de conhecimento do usuário sobre os servi...                      8°
# Falta de pessoal                                                        9°
# Talentos pouco explorados                                              10°
# Falha de comunicação interna entre as equipes                          11°
# Demora no retorno de algumas solicitações                              12°
# Separação física das equipes                                           13°

# %% [markdown]
# # Pontos Fortes

# %%
# Importando os dados do problema (pontos fortes)

forte_a1 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fortes').get_worksheet(0).get_all_records())
forte_a2 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fortes').get_worksheet(1).get_all_records())
forte_a3 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fortes').get_worksheet(2).get_all_records())
forte_a4 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fortes').get_worksheet(3).get_all_records())
# forte_a5 = pd.DataFrame(gc.open('PO/ER460 - Pontos Fortes').get_worksheet(4).get_all_records())

# %%
# tornando as alternativas como índices
def indice(df):
  df = df.set_index('Alternativas/Critérios')
  df.index.names = [None]
  return df

forte_a1 = indice(forte_a1)
forte_a2 = indice(forte_a2)
forte_a3 = indice(forte_a3)
forte_a4 = indice(forte_a4)
# forte_a5 = indice(forte_a5)

# %%
# criando uma escala numérica e passando para o df
def escala(df):
  dic = {'Muito Alto':5, 'Alto':4 , 'Médio':3, 'Baixo':2, 'Muito Baixo':1}
  df['Missão'] = df['Missão'].map(dic)
  df['Visão'] = df['Visão'].map(dic)
  return df

forte_a1 = escala(forte_a1)
forte_a2 = escala(forte_a2)
forte_a3 = escala(forte_a3)
forte_a4 = escala(forte_a4)
# forte_a5 = escala(forte_a5)

# %%
# criando função para calcular a matriz de preferência M
def M_forte(df, w):
  m_pot_oport = f_pref(df, 'Pot. Oport', 'max', 'linear', q=1, p=4)
  m_neut_ame = f_pref(df, 'Neut. Ameaça', 'max', 'linear', q=1, p=4)
  m_missao = f_pref(df, 'Missão', 'max')
  m_visao = f_pref(df, 'Visão', 'max')

  matrizes = [m_pot_oport, m_neut_ame, m_missao, m_visao]

  M = 0
  for i in range(0, len(matrizes)):
    M = M + w[i]*matrizes[i]

  return M

# vetor de pesos
w_forte = [0.10, 0.17, 0.25, 0.48]

# cálculo das matrizes de preferência para cada decisor (pontos fortes):
M_a1 = M_forte(forte_a1, w_forte)
M_a2 = M_forte(forte_a2, w_forte)
M_a3 = M_forte(forte_a3, w_forte)
M_a4 = M_forte(forte_a4, w_forte)
# M_a5 = M_forte(forte_a5, w_forte)

# %%
# calculando o fluxo líquido
def fl_forte(M):
  fl = fluxo_liq(fluxo_pos(M), fluxo_neg(M))
  return fl

fl_a1 = fl_forte(M_a1)
fl_a2 = fl_forte(M_a2)
fl_a3 = fl_forte(M_a3)
fl_a4 = fl_forte(M_a4)
# fl_a5 = fl_forte(M_a5)

# %%
# # função para ordenamento
# def ordenamento(df, fl):
#   # gerando um dicionário para ranking
#   rank = {}
#   for i in range(0, len(df)):
#     rank.update({df.index.values[i] : fl[i]})

#   # gerando a ordem (decrescente)
#   ordem = []
#   for i in sorted(rank, key=rank.get, reverse=True):
#     ordem.append(i)
#     # print(i, rank[i])

#   print('O ranking das oportunidades é:')
#   for i in range(0, len(ordem)):
#     print(f'{i+1}° - {ordem[i]}')

# %%
# função para ordenamento
def ordenamento(decisor, df, fl):
  # gerando um dicionário para ranking
  rank = {}
  for i in range(0, len(df)):
    rank.update({df.index.values[i] : fl[i]})

  tabela = pd.DataFrame(pd.Series(rank), columns=['Fluxo Líquido'])

  tabela = tabela.sort_values(by='Fluxo Líquido', ascending=False)

  ord = []
  for i in range(0, len(df)):
    ord.append(i+1)

  tabela[f'Rank D{decisor}'] = ord

  return tabela

# %%
print('Avaliador 1:')
print(ordenamento(1, forte_a1, fl_a1))
print(80*'-')
print('Avaliador 2:')
print(ordenamento(2, forte_a2, fl_a2))
print(80*'-')
print('Avaliador 3:')
print(ordenamento(3, forte_a3, fl_a3))
print(80*'-')
print('Avaliador 4:')
print(ordenamento(4, forte_a4, fl_a4))
# print(80*'-')
# print('Avaliador 5:')
# print(ordenamento(5, forte_a5, fl_a5))
# Out:
# Avaliador 1:
#                                                     Fluxo Líquido  Rank D1
# Profissionais engajados                                  0.643556        1
# Qualidade técnica dos profissionais                      0.624667        2
# Incentivo à novas iniciativas                            0.529333        3
# Visão sistemica                                          0.506667        4
# Conhecimento abrangente e disseminável                   0.491111        5
# Papel atuante como suporte à tomada de decisões...       0.491111        6
# Ações geram impacto na Comunidade                        0.407556        7
# Autonomia e confiança na tomada de decisões             -0.097333        8
# Clareza e detalhamento dos procedimentos e proc...      -0.340889        9
# Comunicação interna                                     -0.351111       10
# Coerência na composição da DEPI frente a estrut...      -0.402222       11
# Incetivo à capacitação                                  -0.439111       12
# Equipe e ambiente                                       -0.508000       13
# Boa comunicação com usuários                            -0.508000       14
# Boa infraestrutura e boas condições de trabalho         -0.510444       15
# Bom atendimento                                         -0.536889       16
# --------------------------------------------------------------------------------
# Avaliador 2:
#                                                     Fluxo Líquido  Rank D2
# Qualidade técnica dos profissionais                      0.558667        1
# Visão sistemica                                          0.554667        2
# Autonomia e confiança na tomada de decisões              0.505778        3
# Papel atuante como suporte à tomada de decisões...       0.427778        4
# Incetivo à capacitação                                   0.378444        5
# Incentivo à novas iniciativas                            0.308667        6
# Coerência na composição da DEPI frente a estrut...       0.290889        7
# Conhecimento abrangente e disseminável                   0.031333        8
# Ações geram impacto na Comunidade                       -0.006444        9
# Equipe e ambiente                                       -0.104444       10
# Profissionais engajados                                 -0.328222       11
# Clareza e detalhamento dos procedimentos e proc...      -0.402889       12
# Boa comunicação com usuários                            -0.402889       13
# Comunicação interna                                     -0.524889       14
# Boa infraestrutura e boas condições de trabalho         -0.524889       15
# Bom atendimento                                         -0.761556       16
# --------------------------------------------------------------------------------
# Avaliador 3:
#                                                     Fluxo Líquido  Rank D3
# Profissionais engajados                                  0.735111        1
# Qualidade técnica dos profissionais                      0.384000        2
# Visão sistemica                                          0.318889        3
# Comunicação interna                                      0.176222        4
# Bom atendimento                                          0.152000        5
# Incetivo à capacitação                                   0.130000        6
# Boa comunicação com usuários                             0.121333        7
# Papel atuante como suporte à tomada de decisões...       0.071333        8
# Boa infraestrutura e boas condições de trabalho          0.032000        9
# Incentivo à novas iniciativas                           -0.030444       10
# Ações geram impacto na Comunidade                       -0.121333       11
# Clareza e detalhamento dos procedimentos e proc...      -0.307778       12
# Equipe e ambiente                                       -0.331556       13
# Coerência na composição da DEPI frente a estrut...      -0.372667       14
# Autonomia e confiança na tomada de decisões             -0.439778       15
# Conhecimento abrangente e disseminável                  -0.517333       16
# --------------------------------------------------------------------------------
# Avaliador 4:
#                                                     Fluxo Líquido  Rank D4
# Qualidade técnica dos profissionais                      0.732889        1
# Profissionais engajados                                  0.661111        2
# Conhecimento abrangente e disseminável                   0.593111        3
# Ações geram impacto na Comunidade                        0.502444        4
# Incetivo à capacitação                                   0.119111        5
# Visão sistemica                                          0.062444        6
# Coerência na composição da DEPI frente a estrut...      -0.009333        7
# Incentivo à novas iniciativas                           -0.039556        8
# Boa comunicação com usuários                            -0.044000        9
# Clareza e detalhamento dos procedimentos e proc...      -0.078222       10
# Papel atuante como suporte à tomada de decisões...      -0.130222       11
# Equipe e ambiente                                       -0.137333       12
# Autonomia e confiança na tomada de decisões             -0.165333       13
# Comunicação interna                                     -0.507556       14
# Boa infraestrutura e boas condições de trabalho         -0.745778       15
# Bom atendimento                                         -0.813778       16

# %%
# gerando as tabelas para cada decisor (pontos fortes)
ordem_forte_a1 = ordenamento(1, forte_a1, fl_a1)
ordem_forte_a2 = ordenamento(2, forte_a2, fl_a2)
ordem_forte_a3 = ordenamento(3, forte_a3, fl_a3)
ordem_forte_a4 = ordenamento(4, forte_a4, fl_a4)
# ordem_forte_a5 = ordenamento(5, forte_a5, fl_a5)

# criando um dataframe com os ordenamento de todos os decisores:
pont_fortes = pd.concat([ordem_forte_a1, ordem_forte_a2, ordem_forte_a3, ordem_forte_a4], axis=1)
pont_fortes = pont_fortes.drop(['Fluxo Líquido'], axis=1)
pont_fortes
# Out:
#                                                     Rank D1  Rank D2  Rank D3  \
# Profissionais engajados                                   1       11        1
# Qualidade técnica dos profissionais                       2        1        2
# Incentivo à novas iniciativas                             3        6       10
# Visão sistemica                                           4        2        3
# Conhecimento abrangente e disseminável                    5        8       16
# Papel atuante como suporte à tomada de decisões...        6        4        8
# Ações geram impacto na Comunidade                         7        9       11
# Autonomia e confiança na tomada de decisões               8        3       15
# Clareza e detalhamento dos procedimentos e proc...        9       12       12
# Comunicação interna                                      10       14        4
# Coerência na composição da DEPI frente a estrut...       11        7       14
# Incetivo à capacitação                                   12        5        6
# Equipe e ambiente                                        13       10       13
# Boa comunicação com usuários                             14       13        7
# Boa infraestrutura e boas condições de trabalho          15       15        9
# Bom atendimento                                          16       16        5
#
#                                                     Rank D4
# Profissionais engajados                                   2
# Qualidade técnica dos profissionais                       1
# Incentivo à novas iniciativas                             8
# Visão sistemica                                           6
# Conhecimento abrangente e disseminável                    3
# Papel atuante como suporte à tomada de decisões...       11
# Ações geram impacto na Comunidade                         4
# Autonomia e confiança na tomada de decisões              13
# Clareza e detalhamento dos procedimentos e proc...       10
# Comunicação interna                                      14
# Coerência na composição da DEPI frente a estrut...        7
# Incetivo à capacitação                                    5
# Equipe e ambiente                                        12
# Boa comunicação com usuários                              9
# Boa infraestrutura e boas condições de trabalho          15
# Bom atendimento                                          16

# %%
#@title Decisão em Grupo (Borda):
# criando uma escala para borda
borda_forte = {}
for i in range(0, len(pont_fortes)):
  borda_forte.update({i+1: (len(pont_fortes)-i)})

peso_dirigente = 1.2
borda_forte_dirig = {}
for i in range(0, len(pont_fortes)):
  borda_forte_dirig.update({i+1: (len(pont_fortes)-i)*peso_dirigente})

# substituindo os valores de ordenamento pelo valor da escala de Borda
# Ex: (1,2,3) vai virar (3,2,1)
for i in pont_fortes.columns:
  if i == pont_fortes.columns[0]: # se o decisor for a dirigente (peso maior)
    pont_fortes[i] = pont_fortes[i].map(borda_forte_dirig)
  else:
    pont_fortes[i] = pont_fortes[i].map(borda_forte)

# somando os valores de cada alternativa
pont_fortes['Valor'] = pont_fortes.sum(axis=1)
# pont_fortes

pont_fortes_final = pd.DataFrame(pont_fortes['Valor'])
pont_fortes_final = pont_fortes_final.sort_values(by='Valor', ascending=False)

ord = []
for i in range(0, len(pont_fortes_final)):
  ord.append(f'{i+1}°')

pont_fortes_final['Ordem Final (Borda)'] = ord
pont_fortes_final
# Out:
#                                                     Valor Ordem Final (Borda)
# Qualidade técnica dos profissionais                  65.0                  1°
# Profissionais engajados                              56.2                  2°
# Visão sistemica                                      55.6                  3°
# Incentivo à novas iniciativas                        43.8                  4°
# Papel atuante como suporte à tomada de decisões...   41.2                  5°
# Incetivo à capacitação                               41.0                  6°
# Ações geram impacto na Comunidade                    39.0                  7°
# Conhecimento abrangente e disseminável               38.4                  8°
# Autonomia e confiança na tomada de decisões          30.8                  9°
# Coerência na composição da DEPI frente a estrut...   30.2                 10°
# Comunicação interna                                  27.4                 11°
# Clareza e detalhamento dos procedimentos e proc...   26.6                 12°
# Boa comunicação com usuários                         25.6                 13°
# Equipe e ambiente                                    20.8                 14°
# Bom atendimento                                      15.2                 15°
# Boa infraestrutura e boas condições de trabalho      14.4                 16°

# %%
#@title Decisão em Grupo (Condorcet):

ordem_forte_a1 = ordenamento(1, forte_a1, fl_a1)
ordem_forte_a2 = ordenamento(2, forte_a2, fl_a2)
ordem_forte_a3 = ordenamento(3, forte_a3, fl_a3)
ordem_forte_a4 = ordenamento(4, forte_a4, fl_a4)

candidatos = ordem_forte_a1.index.values
candidatos = list(candidatos)

lista_forte = [ordem_forte_a1, ordem_forte_a2, ordem_forte_a3, ordem_forte_a4]
votos = voto(lista_forte)

# usando as funções da biblioteca condorcet para definir o ordenamento
evaluator = condorcet.CondorcetEvaluator(candidates=candidatos, votes=votos)
winners, rest_of_table = evaluator.get_n_winners(len(ordem_forte_a1))

forte_condorcet = pd.DataFrame(index=winners)

ord = []
for i in range(0, len(forte_condorcet)):
  ord.append(f'{i+1}°')
forte_condorcet['Ordem Final (Condorcet)'] = ord

forte_condorcet
# Out:
#                                                    Ordem Final (Condorcet)
# Profissionais engajados                                                 1°
# Qualidade técnica dos profissionais                                     2°
# Visão sistemica                                                         3°
# Papel atuante como suporte à tomada de decisões...                      4°
# Incetivo à capacitação                                                  5°
# Incentivo à novas iniciativas                                           6°
# Conhecimento abrangente e disseminável                                  7°
# Ações geram impacto na Comunidade                                       8°
# Autonomia e confiança na tomada de decisões                             9°
# Clareza e detalhamento dos procedimentos e proc...                     10°
# Comunicação interna                                                    11°
# Coerência na composição da DEPI frente a estrut...                     12°
# Equipe e ambiente                                                      13°
# Boa comunicação com usuários                                           14°
# Boa infraestrutura e boas condições de trabalho                        15°
# Bom atendimento                                                        16°
